# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A51L58/NLP/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical

# Parameters
batch_size = 64
epochs = 100
latent_dim = 256
input_vocab_size = 100  # adjust based on actual vocab size
target_vocab_size = 100  # adjust based on actual vocab size

# Sample data (use your own dataset)
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# Vocabulary creation
input_texts = [pair[0] for pair in data]
target_texts = [pair[1] for pair in data]

# Create a mapping of unique tokens for both input and target sequences
input_tokens = sorted(set(" ".join(input_texts).split()))
target_tokens = sorted(set(" ".join(target_texts).split()))

input_token_index = dict([(char, i + 1) for i, char in enumerate(input_tokens)])
target_token_index = dict([(char, i + 1) for i, char in enumerate(target_tokens)])

input_vocab_size = len(input_token_index) + 1
target_vocab_size = len(target_token_index) + 1

# Encode sentences into sequences of integers
def encode_text(text, token_index, max_len):
    sequence = [token_index[word] for word in text.split() if word in token_index]
    sequence = sequence + [0] * (max_len - len(sequence))  # Pad sequences
    return sequence

# Determine maximum lengths for padding
max_encoder_seq_length = max([len(text.split()) for text in input_texts])
max_decoder_seq_length = max([len(text.split()) for text in target_texts])

# Prepare the data
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype="int32")
decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length), dtype="int32")
decoder_target_data = np.zeros((len(target_texts), max_decoder_seq_length, target_vocab_size), dtype="float32")

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    encoder_input_data[i] = encode_text(input_text, input_token_index, max_encoder_seq_length)
    decoder_input_data[i] = encode_text(target_text, target_token_index, max_decoder_seq_length)
    for t, word in enumerate(target_text.split()):
        if word in target_token_index:
            decoder_target_data[i, t, target_token_index[word]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.0  # Shifts the target sequence

# Model definition
# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=input_vocab_size, output_dim=latent_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=target_vocab_size, output_dim=latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(target_vocab_size, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer=RMSprop(), loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Inference models
# Encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model for inference
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Translation function
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))
    start_token_index = 1 if target_token_index else 0  # Default to 0 if empty
    target_seq[0, 0] = start_token_index

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        reverse_target_token_index = dict((i, char) for char, i in target_token_index.items())
        sampled_word = reverse_target_token_index[sampled_token_index]
        decoded_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop character.
        if (sampled_word == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# Test the translation
test_input_seq = np.array(encode_text("hello", input_token_index, max_encoder_seq_length)).reshape(1, -1)
translated_sentence = decode_sequence(test_input_seq)
print("Translated sentence:", translated_sentence)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 9s 9s/step - accuracy: 0.0667 - loss: 3.3476 - val_accuracy: 0.0000e+00 - val_loss: 1.7760
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.2667 - loss: 3.3012 - val_accuracy: 0.0000e+00 - val_loss: 1.7928
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 3.2615 - val_accuracy: 0.0000e+00 - val_loss: 1.8095
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.6000 - loss: 3.2214 - val_accuracy: 0.0000e+00 - val_loss: 1.8277
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.5333 - loss: 3.1779 - val_accuracy: 0.0000e+00 - val_loss: 1.8485
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.6000 - loss: 3.1288 - val_accuracy: 0.0000e+00 - val_loss: 1.8729
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.6000 - loss: 3.0720 - val_accuracy: 0.0000e+00 - val_loss: 1.9020
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6000 - loss: 3.0052 - val_accuracy: 0.0000e+00 - val_loss: 1.9370
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.6000 - loss: 2.9260 - val_accuracy: 0.0000e+00 - val_loss: 1.9793
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6000 - loss: 2.8317 - val_accuracy: 0.0000e+00 - val_loss: 2.0302
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6000 - loss: 2.7195 - val_accuracy: 0.0000e+00 - val_loss: 2.0904
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.6000 - loss: 2.5873 - val_accuracy: 0.0000e+00 - val_loss: 2.1600
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.6000 - loss: 2.4348 - val_accuracy: 0.0000e+00 - val_loss: 2.2373
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.4667 - loss: 2.2652 - val_accuracy: 0.0000e+00 - val_loss: 2.3193
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 89ms/step - accuracy: 0.4667 - loss: 2.0868 - val_accuracy: 0.0000e+00 - val_loss: 2.4025
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 1.9111 - val_accuracy: 0.0000e+00 - val_loss: 2.4846
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4667 - loss: 1.7479 - val_accuracy: 0.0000e+00 - val_loss: 2.5661
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5333 - loss: 1.6016 - val_accuracy: 0.0000e+00 - val_loss: 2.6516
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 1.4730 - val_accuracy: 0.0000e+00 - val_loss: 2.7509
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.3600 - val_accuracy: 0.0000e+00 - val_loss: 2.8770
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5333 - loss: 1.2599 - val_accuracy: 0.0000e+00 - val_loss: 3.0461
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5333 - loss: 1.1707 - val_accuracy: 0.0000e+00 - val_loss: 3.2767
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.0917 - val_accuracy: 0.0000e+00 - val_loss: 3.5870
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 1.0222 - val_accuracy: 0.0000e+00 - val_loss: 3.9858
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 0.9618 - val_accuracy: 0.0000e+00 - val_loss: 4.4586
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.5333 - loss: 0.9110 - val_accuracy: 0.0000e+00 - val_loss: 4.9938
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.5333 - loss: 0.8881 - val_accuracy: 0.0000e+00 - val_loss: 5.2914
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.6000 - loss: 1.1577 - val_accuracy: 0.0000e+00 - val_loss: 5.7784
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4667 - loss: 1.0660 - val_accuracy: 0.0000e+00 - val_loss: 6.0039
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.6000 - loss: 0.8722 - val_accuracy: 0.0000e+00 - val_loss: 6.5130
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4000 - loss: 0.8826 - val_accuracy: 0.0000e+00 - val_loss: 6.6805
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.5333 - loss: 0.9582 - val_accuracy: 0.0000e+00 - val_loss: 7.1107
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4667 - loss: 0.9042 - val_accuracy: 0.0000e+00 - val_loss: 7.2303
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.6000 - loss: 0.8400 - val_accuracy: 0.0000e+00 - val_loss: 7.8590
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4000 - loss: 0.8174 - val_accuracy: 0.0000e+00 - val_loss: 8.1497
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5333 - loss: 0.7972 - val_accuracy: 0.0000e+00 - val_loss: 8.6418
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4000 - loss: 0.7907 - val_accuracy: 0.0000e+00 - val_loss: 8.8808
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4667 - loss: 0.8021 - val_accuracy: 0.0000e+00 - val_loss: 9.3634
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4000 - loss: 0.7939 - val_accuracy: 0.0000e+00 - val_loss: 9.5320
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4667 - loss: 0.7950 - val_accuracy: 0.0000e+00 - val_loss: 10.1245
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4000 - loss: 0.7868 - val_accuracy: 0.0000e+00 - val_loss: 10.1994
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.5333 - loss: 0.7811 - val_accuracy: 0.0000e+00 - val_loss: 10.8205
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 320ms/step - accuracy: 0.4000 - loss: 0.7800 - val_accuracy: 0.0000e+00 - val_loss: 10.7839
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 0.7762 - val_accuracy: 0.0000e+00 - val_loss: 11.4742
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4000 - loss: 0.7782 - val_accuracy: 0.0000e+00 - val_loss: 11.2351
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 0.7786 - val_accuracy: 0.0000e+00 - val_loss: 12.1841
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4667 - loss: 0.7913 - val_accuracy: 0.0000e+00 - val_loss: 11.3975
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 128ms/step - accuracy: 0.5333 - loss: 0.8237 - val_accuracy: 0.0000e+00 - val_loss: 12.6994
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.5333 - loss: 0.8628 - val_accuracy: 0.0000e+00 - val_loss: 12.1930
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step - accuracy: 0.5333 - loss: 0.8182 - val_accuracy: 0.0000e+00 - val_loss: 13.0066
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.4667 - loss: 0.7861 - val_accuracy: 0.0000e+00 - val_loss: 12.9142
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4000 - loss: 0.7519 - val_accuracy: 0.0000e+00 - val_loss: 13.5238
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step - accuracy: 0.4667 - loss: 0.7605 - val_accuracy: 0.0000e+00 - val_loss: 13.2203
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 286ms/step - accuracy: 0.4667 - loss: 0.7521 - val_accuracy: 0.0000e+00 - val_loss: 14.0428
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.4667 - loss: 0.7722 - val_accuracy: 0.0000e+00 - val_loss: 13.6821
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 291ms/step - accuracy: 0.5333 - loss: 0.7539 - val_accuracy: 0.0000e+00 - val_loss: 14.5116
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 182ms/step - accuracy: 0.4667 - loss: 0.7695 - val_accuracy: 0.0000e+00 - val_loss: 14.1944
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 220ms/step - accuracy: 0.5333 - loss: 0.7540 - val_accuracy: 0.0000e+00 - val_loss: 14.9565
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.4667 - loss: 0.7622 - val_accuracy: 0.0000e+00 - val_loss: 14.6942
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step - accuracy: 0.6000 - loss: 0.7654 - val_accuracy: 0.0000e+00 - val_loss: 15.3929
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4667 - loss: 0.7602 - val_accuracy: 0.0000e+00 - val_loss: 15.1610
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.6000 - loss: 0.7721 - val_accuracy: 0.0000e+00 - val_loss: 15.8072
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.7566 - val_accuracy: 0.0000e+00 - val_loss: 15.6421
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 0.7480 - val_accuracy: 0.0000e+00 - val_loss: 16.1917
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4667 - loss: 0.7462 - val_accuracy: 0.0000e+00 - val_loss: 16.1220
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4000 - loss: 0.7420 - val_accuracy: 0.0000e+00 - val_loss: 16.5475
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 93ms/step - accuracy: 0.4667 - loss: 0.7407 - val_accuracy: 0.0000e+00 - val_loss: 16.5886
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.4000 - loss: 0.7358 - val_accuracy: 0.0000e+00 - val_loss: 16.8852
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.7363 - val_accuracy: 0.0000e+00 - val_loss: 17.0566
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.4000 - loss: 0.7342 - val_accuracy: 0.0000e+00 - val_loss: 17.2235
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 123ms/step - accuracy: 0.4667 - loss: 0.7301 - val_accuracy: 0.0000e+00 - val_loss: 17.5001
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.5333 - loss: 0.7446 - val_accuracy: 0.0000e+00 - val_loss: 17.5583
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.7286 - val_accuracy: 0.0000e+00 - val_loss: 17.9327
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.5333 - loss: 0.7710 - val_accuracy: 0.0000e+00 - val_loss: 17.8330
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7284 - val_accuracy: 0.0000e+00 - val_loss: 18.3157
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 92ms/step - accuracy: 0.5333 - loss: 0.7462 - val_accuracy: 0.0000e+00 - val_loss: 17.9834
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4667 - loss: 0.7152 - val_accuracy: 0.0000e+00 - val_loss: 18.5457
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4667 - loss: 0.7388 - val_accuracy: 0.0000e+00 - val_loss: 18.4052
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4667 - loss: 0.7104 - val_accuracy: 0.0000e+00 - val_loss: 18.8433
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.4667 - loss: 0.7556 - val_accuracy: 0.0000e+00 - val_loss: 17.4769
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 134ms/step - accuracy: 0.4667 - loss: 0.7130 - val_accuracy: 0.0000e+00 - val_loss: 17.9700
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4667 - loss: 0.7293 - val_accuracy: 0.0000e+00 - val_loss: 18.6649
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 229ms/step - accuracy: 0.4667 - loss: 0.7123 - val_accuracy: 0.0000e+00 - val_loss: 18.9218
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step - accuracy: 0.4667 - loss: 0.7385 - val_accuracy: 0.0000e+00 - val_loss: 19.1728
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - accuracy: 0.4667 - loss: 0.7265 - val_accuracy: 0.0000e+00 - val_loss: 18.8958
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4667 - loss: 0.7367 - val_accuracy: 0.0000e+00 - val_loss: 19.4470
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step - accuracy: 0.4000 - loss: 0.7830 - val_accuracy: 0.0000e+00 - val_loss: 16.7931
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step - accuracy: 0.4000 - loss: 0.7262 - val_accuracy: 0.0000e+00 - val_loss: 17.8436
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step - accuracy: 0.4667 - loss: 0.6996 - val_accuracy: 0.0000e+00 - val_loss: 18.4624
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.4667 - loss: 0.7146 - val_accuracy: 0.0000e+00 - val_loss: 18.9698
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.4667 - loss: 0.6986 - val_accuracy: 0.0000e+00 - val_loss: 19.2945
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - accuracy: 0.4667 - loss: 0.7203 - val_accuracy: 0.0000e+00 - val_loss: 19.3416
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 151ms/step - accuracy: 0.4667 - loss: 0.7069 - val_accuracy: 0.0000e+00 - val_loss: 19.3776
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4000 - loss: 0.7258 - val_accuracy: 0.0000e+00 - val_loss: 19.4241
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - accuracy: 0.4667 - loss: 0.7148 - val_accuracy: 0.0000e+00 - val_loss: 19.0475
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4000 - loss: 0.7250 - val_accuracy: 0.0000e+00 - val_loss: 19.5417
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4667 - loss: 0.7067 - val_accuracy: 0.0000e+00 - val_loss: 19.3530
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.4000 - loss: 0.7260 - val_accuracy: 0.0000e+00 - val_loss: 19.5649
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 263ms/step - accuracy: 0.4667 - loss: 0.7043 - val_accuracy: 0.0000e+00 - val_loss: 19.3938
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4000 - loss: 0.7240 - val_accuracy: 0.0000e+00 - val_loss: 19.6228
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 274ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 409ms/step
# Translated sentence: bonjour
